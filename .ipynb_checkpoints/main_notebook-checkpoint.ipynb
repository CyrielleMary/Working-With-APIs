# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import json
from pandas import json_normalize

# %% [markdown]
# ## Disney

# %%
url = 'https://api.disneyapi.dev/character'

# %%
response = requests.get(url)
results = response.json()
type(results)
# Out:
# dict

# %%
#results

# %%
list(results)
# Out:
# ['info', 'data']

# %%
results['data']
pd.DataFrame(list(results['data']))
# Out:
#     _id                                              films shortFilms  \
# 0   112                                  [Hercules (film)]         []
# 1    18   [The Fox and the Hound, The Fox and the Hound 2]         []
# 2    16                                          [Cheetah]         []
# 3    45        [Mary Poppins (film), Mary Poppins Returns]         []
# 4     7                                                 []         []
# 5    12                                                 []         []
# 6    36                                                 []         []
# 7   139         [The Lion King, The Lion King (2019 film)]         []
# 8   152                                                 []         []
# 9   181                                                 []         []
# 10  204            [The Robber Kitten, Mickey's Polo Team]         []
# 11  215                                       [Ben and Me]         []
# ...

# %% [markdown]
# ## Tender Hungary

# %%
url = 'https://tenders.guru/api/hu/tenders'

# %%
response = requests.get(url)
#results = response.json()
#response.content
# type(results)

# %%
results = response.json()

# %%
#results

# %%
results['data']
pd.DataFrame(list(results['data']))
# Out:
#        id        date deadline_date  \
# 0   36077  2021-08-01    2021-08-12
# 1   36073  2021-09-26    2021-10-07
# 2   36067  2021-01-17    2021-01-28
# 3   36060  2021-01-28    2021-03-03
# 4   36059  2021-10-21    2021-11-03
# ..    ...         ...           ...
# 95  35839  2021-09-28    2021-10-25
# 96  35775  2021-09-07    2021-09-24
# 97  35542  2021-09-20    2021-09-28
# 98  35337  2021-09-16    2021-10-05
# 99  35330  2021-10-04    2021-10-20
#
#                                                 title       category  \
# 0   "Régészeti feltárásokhoz szükséges kézi földmu...  constructions
# 1              Cserepes és Szélmalom utcák felújítása  constructions
# 2    Bölcsőde építése Dömösön – TOP-1.4.1-19-KO1-2019  constructions
# 3                      Építési beruházás - EFOP-2.4.1  constructions
# 4                       Felszíni vízrendezés I. üteme  constructions
# ..                                                ...            ...
# ...

# %%
url='https://api.chucknorris.io/jokes/random'

# %%
response = requests.get(url)
#results = response.json()
response.content
# type(results)
# Out:
# b'{"categories":[],"created_at":"2020-01-05 13:42:28.420821","icon_url":"https://assets.chucknorris.host/img/avatar/chuck-norris.png","id":"7AQRr-8KSxakMezgFDwpzQ","updated_at":"2020-01-05 13:42:28.420821","url":"https://api.chucknorris.io/jokes/7AQRr-8KSxakMezgFDwpzQ","value":"Chuck Norris is the one. Not Keanu Reeves, or Jet Li, and DEFINATELY not Christopher Lambert."}'

# %%
results = response.json()

# %%
results['value']
# pd.DataFrame(list(results['categories']))
# Out:
# 'Chuck Norris is the one. Not Keanu Reeves, or Jet Li, and DEFINATELY not Christopher Lambert.'

# %%
url = 'https://api.openbrewerydb.org/v1/breweries'

# %%
response = requests.get(url)
#response.content
# type(results)

# %%
results = response.json()

# %%
type(results)
# Out:
# list

# %%
res = json_normalize(results)

# %%
res
# Out:
#                                       id  \
# 0   5128df48-79fc-4f0f-8b52-d06be54d0cec
# 1   9c5a66c8-cc13-416f-a5d9-0a769c87d318
# 2   34e8c68b-6146-453f-a4b9-1f6cd99a5ada
# 3   ef970757-fe42-416f-931d-722451f1f59c
# 4   6d14b220-8926-4521-8d19-b98a2d6ec3db
# 5   e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2
# 6   e432899b-7f58-455f-9c7b-9a6e2130a1e0
# 7   9f1852da-c312-42da-9a31-097bac81c4c0
# 8   ea4f30c0-bce6-416b-8904-fab4055a7362
# 9   1988eb86-f0a2-4674-ba04-02454efa0d31
# 10  1ecc330f-6275-42a5-b14e-00adbed62752
# 11  7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 12  03118499-a3d0-4c22-860d-4529509ae095
# 13  5ae467af-66dc-4d7f-8839-44228f89b596
# 14  4ffda196-dd59-44a5-9eeb-5f7fd4b58f5a
# 15  42aa37d5-8384-4ffe-8c81-7c982eff0384
# 16  232e8f62-9afc-45f5-b4bc-582c26b5c43b
# 17  08f78223-24f8-4b71-b381-ea19a5bd82df
# 18  58293321-14ae-49d7-9a7b-08436c9e63a6
# 19  e5f3e72a-fee2-4813-82cf-f2e53b439ae6
# 20  d81ff708-b5d2-478f-af6a-6d40f5beb9ac
# 21  fb94830f-6196-4f59-9189-c9060b778085
# ...
